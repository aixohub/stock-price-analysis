# %%
import warnings
# !pip3 install cufflinks
# !pip3 install plotly==5.24.1


import numpy as np
import pandas as pd
import cufflinks as cf
import plotly.offline as plyo

warnings.filterwarnings('ignore')
# Out:
# 930.70s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: cufflinks in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (0.17.3)
# Requirement already satisfied: numpy>=1.9.2 in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from cufflinks) (2.0.2)
# Requirement already satisfied: ipython>=5.3.0 in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from cufflinks) (8.18.1)
# Requirement already satisfied: plotly>=4.1.1 in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from cufflinks) (5.24.1)
# Requirement already satisfied: pandas>=0.19.2 in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from cufflinks) (2.2.3)
# Requirement already satisfied: colorlover>=0.2.1 in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: setuptools>=34.4.1 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from cufflinks) (58.0.4)
# Requirement already satisfied: six>=1.9.0 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from cufflinks) (1.15.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from cufflinks) (8.1.5)
# Requirement already satisfied: traitlets>=5 in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from ipython>=5.3.0->cufflinks) (5.14.3)
# Requirement already satisfied: exceptiongroup in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from ipython>=5.3.0->cufflinks) (1.2.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from ipython>=5.3.0->cufflinks) (3.0.48)
# Requirement already satisfied: decorator in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from ipython>=5.3.0->cufflinks) (5.1.1)
# Requirement already satisfied: stack-data in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from ipython>=5.3.0->cufflinks) (0.6.3)
# Requirement already satisfied: jedi>=0.16 in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from ipython>=5.3.0->cufflinks) (0.19.1)
# Requirement already satisfied: typing-extensions in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from ipython>=5.3.0->cufflinks) (4.12.2)
# Requirement already satisfied: pexpect>4.3 in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from ipython>=5.3.0->cufflinks) (4.9.0)
# Requirement already satisfied: matplotlib-inline in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from ipython>=5.3.0->cufflinks) (0.1.7)
# Requirement already satisfied: pygments>=2.4.0 in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from ipython>=5.3.0->cufflinks) (2.18.0)
# Requirement already satisfied: comm>=0.1.3 in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.2)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.13)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython>=5.3.0->cufflinks) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from pandas>=0.19.2->cufflinks) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from pandas>=0.19.2->cufflinks) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from pandas>=0.19.2->cufflinks) (2024.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from pexpect>4.3->ipython>=5.3.0->cufflinks) (0.7.0)
# Requirement already satisfied: packaging in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from plotly>=4.1.1->cufflinks) (24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from plotly>=4.1.1->cufflinks) (9.0.0)
# Requirement already satisfied: wcwidth in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks) (0.2.13)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=5.3.0->cufflinks) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=5.3.0->cufflinks) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=5.3.0->cufflinks) (2.1.0)
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# 936.68s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: plotly==5.24.1 in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (5.24.1)
# Requirement already satisfied: packaging in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from plotly==5.24.1) (24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/jupyternote/Library/Python/3.9/lib/python/site-packages (from plotly==5.24.1) (9.0.0)
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
plyo.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
a = np.random.standard_normal((250, 5)).cumsum(axis=0)
index = pd.date_range('2023-1-1',  freq='B', periods=len(a))
df = pd.DataFrame(100 + 5 * a, columns=list('abcde'), index=index)
df.head()
# Out:
#                     a          b           c           d           e
# 2023-01-02  99.493806  93.569041  103.248851   93.377380  100.608810
# 2023-01-03  91.983577  96.451722  108.937905  102.608570  104.639104
# 2023-01-04  87.092389  99.438561  110.221169  104.204606  108.911305
# 2023-01-05  88.860166  97.920790  110.622851  100.004161  115.405997
# 2023-01-06  92.440949  91.272384  112.954775  105.015116  110.893333

# %%
plyo.iplot(df[['a', 'b']].iplot(asFigure=True,
                          theme='polar',
                          title='A Time Series Plot',
                          xTitle='date',
                          yTitle='value',
                          mode={'a': 'markers', 'b': 'lines+markers'},
                          symbol={'a': 'circle', 'b': 'diamond'},
                          size=3.5, colors={'a': 'blue', 'b': 'magenta'}, filename='ply_01'))
# Out:
# <div>                            <div id="dfaf43f5-50e8-4da1-9ca6-fb2815e994f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dfaf43f5-50e8-4da1-9ca6-fb2815e994f6")) {                    Plotly.newPlot(                        "dfaf43f5-50e8-4da1-9ca6-fb2815e994f6",                        [{"line":{"color":"blue","dash":"solid","shape":"linear","width":1.3},"marker":{"size":3.5,"symbol":"circle"},"mode":"markers","name":"a","text":"","x":["2023-01-02","2023-01-03","2023-01-04","2023-01-05","2023-01-06","2023-01-09","2023-01-10","2023-01-11","2023-01-12","2023-01-13","2023-01-16","2023-01-17","2023-01-18","2023-01-19","2023-01-20","2023-01-23","2023-01-24","2023-01-25","2023-01-26","2023-01-27","2023-01-30","2023-01-31","2023-02-01","2023-02-02","2023-02-03","2023-02-06","2023-02-07","2023-02-08","2023-02-09","2023-02-10","2023-02-13","2023-02-14","2023-02-15","2023-02-16","2023-02-17","2023-02-20","2023-02-21","2023-02-22","2023-02-23","2023-02-24","2023-02-27","2023-02-28","2023-03-01","2023-03-02","2023-03-03","2023-03-06","2023-03-07","2023-03-08","2023-03-09","2023-03-10","2023-03-13","2023-03-14